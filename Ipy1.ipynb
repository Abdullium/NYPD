# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\abdul\Desktop\Sample data for assignment - Sheet1.csv")

# %%
df.columns = df.iloc[2]

# %%
df.drop(df.index[0:2], inplace = True)

# %%
df.set_index("DATE",inplace = True)

# %%
df2 = df.groupby("HS CODE")["HS CODE","PRODUCT","QUANTITY"].count()
# Out:
# C:\Users\abdul\AppData\Local\Temp\ipykernel_6636\3119934060.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df2 = df.groupby("HS CODE")["HS CODE","PRODUCT","QUANTITY"].count()

# %%
df2
# Out:
# 2         HS CODE  PRODUCT  QUANTITY
# HS CODE
# 29039990        1        1         1
# 29096000        1        1         1
# 29181320        2        2         2
# 29214290        6        6         6
# 29225021       10       10        10
# 29225090        1        1         1
# 29242990        1        1         1
# 29252990        2        2         2
# 29313900        2        2         2
# 29321990        3        3         3
# 29332990        5        5         5
# 29334900       11       11        11
# 29335920        1        1         1
# 29335990       21       21        21
# 29349990        1        1         1
# 29359090        6        6         6
# 29362990        1        1         1
# 29371900        1        1         1
# 29372300        1        1         1
# 29372900        6        6         6
# 29379090        2        2         2
# 29392040        2        2         2
# 29419090        3        3         3
# 29420027       16       16        16
# ...

# %%
# This Chemical() has been listed 16 times
df[df["HS CODE"] == "29420027"]
# Out:
# 2            HS CODE                                   PRODUCT QUANTITY UNIT  \
# DATE
# 31-12-2020  29420027                   DRUGS: ATENOLOL PH.EUR.      100  KGS
# 30-12-2020  29420027                     DRUGS:ATENOLOL PH.EUR   5358.6  KGS
# 30-12-2020  29420027                   DRUGS: ATENOLOL PH.EUR.       50  KGS
# 30-12-2020  29420027   DRUGS: PROPRANOLOL HYDROCHLORIDE PH.EUR   1083.4  KGS
# 29-12-2020  29420027                        DRUGS: ATENOLOL BP      500  KGS
# 28-12-2020  29420027                    DRUGS: ATENOLOL PH.EUR   2075.3  KGS
# 24-12-2020  29420027                        DRUGS: ATENOLOL BP      100  KGS
# 24-12-2020  29420027                        DRUGS: ATENOLOL BP       25  KGS
# 24-12-2020  29420027                        DRUGS: ATENOLOL BP       75  KGS
# 24-12-2020  29420027                    DRUGS: ATENOLOL PH.EUR     2500  KGS
# 23-12-2020  29420027  DRUGS: PROPRANOLOL HYDROCHLORIDE PH.EUR.      400  KGS
# ...

# %%
#This Chemical(29335990) has been listed 21 times
df[df["HS CODE"] == "29335990"]
# Out:
# 2            HS CODE                                            PRODUCT  \
# DATE
# 31-12-2020  29335990  DRUGS: PYRANTEL PAMOATE PH.EUR. (PYRANTE L PAM...
# 30-12-2020  29335990        DRUGS: CETIRIZINE DI HYDROCHLORIDE PH.EU R.
# 29-12-2020  29335990           DRUGS: PYRANTEL PAMOATE USP (PYRANTEL PA
# 29-12-2020  29335990                        DRUGS: PYRANTEL PAMOATE USP
# 29-12-2020  29335990    DRUGS PYRANTEL PAMOATE USP (PYRANTEL PAM OATE )
# 29-12-2020  29335990                        DRUGS: PYRANTEL PAMOATE USP
# 28-12-2020  29335990                              DRUGS OXANTEL PAMOATE
# 28-12-2020  29335990  DRUGS PYRANTEL PAMOATE PH. EUR (PYRANTE L EMBO...
# 28-12-2020  29335990           DRUGS: PYRANTEL PAMOATE (PYRANTEL PAMOAT
# 28-12-2020  29335990    DRUGS: PYRANTEL PAMOATE (PYRANTEL PAMOAT E USP)
# 24-12-2020  29335990             DRUGS:ALLOPURINOL(ALLOPURINOL Ph.Eur.)
# 24-12-2020  29335990    DRUGS PYRANTEL PAMOATE USP (PYRANTEL PAM OATE )
# ...

# %%
#This Chemical(29225021) has been listed 10 times
df[df["HS CODE"] == "29225021"]
# Out:
# 2            HS CODE                               PRODUCT QUANTITY UNIT  \
# DATE
# 28-12-2020  29225021                      DRUGS FUROSEMIDE     1500  KGS
# 28-12-2020  29225021                   DRUGS FUROSEMIDE BP     1000  KGS
# 28-12-2020  29225021             DRUGS: FUROSEMIDE PH.EUR.   1382.8  KGS
# 28-12-2020  29225021  DRUGS: FUROSEMIDE PH.EUR (FRUSEMIDE)        3  KGS
# 24-12-2020  29225021              DRUGS FUROSEMIDE PH. EUR     1875  KGS
# 23-12-2020  29225021        DRUGS FRUSEMIDE/FUROSEMIDE USP      400  KGS
# 23-12-2020  29225021              DRUGS: FUROSEMIDE PH EUR       25  KGS
# 23-12-2020  29225021  DRUGS: FUROSEMIDE PH.EUR (FRUSEMIDE)      300  KGS
# 23-12-2020  29225021      DRUGS: FUROSEMIDE CP (FRUSEMIDE)       25  KGS
# 22-12-2020  29225021                  DRUGS: FUROSEMIDE BP       50  KGS
#
# 2          UNIT RATE CURRENCY TOTAL USD  DESTINATION  \
# DATE
# 28-12-2020     46.17      USD     70500      DENMARK
# ...

# %%
# These HS CODES following above have been repeated more 47 times in the dataset, 
#Descreasing the quality of data
